# %% [markdown]
# asam mahmood assignment 4

# %% [markdown]
# •Stochastic Gradient Descent Learning: This a type of optimizaqtion algorithm. Helps gind the best paramets for the model to fight the best fit for expected output and actual output. The cost function is optimized in theis proccess by changing decision variables.
#
# •Neural network learning rate: This is a parameter for nueral networks usually from .0 to 1.0. It helps control the models response when the estimated error is change when weights are updated. When value is small the training can take longer.
#
# •Multi-Layer Feed Froward Neural Network:  This is when there are multiple layers of perceptrons in a network. The input data and calculation flow in a single direction to the output.
#
# •Hidden Layerin Neural Network: This is a layer in between input layers of perceptrons and output layers of perceptrons and take the inputs and create a output with a activation function.
#
# •Output Layer in Neural Network: This layer is responsible to create the final output of a nueral network. it takes the inputs which were passed in through layers before it  and does set coputations through its nuerons and then creates final output
#
# •Backpropagation Rule: This very important type of tool in machine learning and helps imprve accuracy of outputs in machinelearning. It is a type of algorithm used to caalulcate derivatives in a very fast way.
#
# •Objective function of Multi-layer Neural Network: Examples of objective functions are  MSE, cross entropy. They help determine how nueral networks work and why they fail depending on use case.
#
# •Momentum term in neural network weight updating: Momentum in neural networks i a type of stochastic gradient descent and it replaces gradien with aggregate of gradients.

# %% [markdown]
# Question 2 [1 pt] Figure 1 shows a single layer neural network with three weight values
# (including bias). Please use gradient descent learning to derive weight updating rule for w0.
# Please define the objective function [0.5 pt] and the derivations [0.5 pt]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import seaborn as sns
from sklearn.model_selection import train_test_split
from IPython.display import display, HTML
np.warnings.filterwarnings('ignore', category=np.VisibleDeprecationWarning)

def compute_RBF(mat1, mat2, sigma):

    trnorms1 = np.mat([(v * v.T)[0, 0] for v in mat1]).T
    trnorms2 = np.mat([(v * v.T)[0, 0] for v in mat2]).T

    k1 = trnorms1 * np.mat(np.ones((mat2.shape[0], 1), dtype=np.float64)).T

    k2 = np.mat(np.ones((mat1.shape[0], 1), dtype=np.float64)) * trnorms2.T

    k = k1 + k2

    k -= 2 * np.mat(mat1 * mat2.T)

    k *= - 1./(2 * np.power(sigma, 2))

    return np.exp(k)

compute_RBF(-1,.5,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-4ee85779455c> in <module>
#      25     return np.exp(k)
#      26
# ---> 27 compute_RBF(1,.5,1)
#
# <ipython-input-3-4ee85779455c> in compute_RBF(mat1, mat2, sigma)
#      10 def compute_RBF(mat1, mat2, sigma):
#      11
# ---> 12     trnorms1 = np.mat([(v * v.T)[0, 0] for v in mat1]).T
#      13     trnorms2 = np.mat([(v * v.T)[0, 0] for v in mat2]).T
#      14
#
# TypeError: 'int' object is not iterable
